# %%
import pandas as pd
import numpy as np

import re

# %%
df = pd.read_csv("../data/processed/twitter-data-small.csv")
sal_df = pd.read_csv("../data/processed/sal.csv")

# %%
state_location = dict(zip([s.lower() for s in ['Australian Capital Territory', 
                                               'New South Wales', 
                                               'Northern Territory', 
                                               'Queensland', 
                                               'South Australia', 
                                               'Tasmania', 'Victoria', 
                                               'Western Australia']], 
                         [s.lower() for s in ['ACT', 'NSW', 
                                              'NT', 'QLD', 'SA', 
                                              'TAS', 'VIC', 'WA']]))

city_location = dict(zip([s.lower() for s in ['Canberra', 'Sydney', 'Darwin', 'Brisbane', 'Adelaide', 'Hobart', 'Melbourne', 'Perth']],
                         [s.lower() for s in ['CAN', 'SYD', 'DAR', 'BRI', 'ADE', 'HOB', 'MEL', 'PER']]))

# %%
state_location, city_location
# Out:
# ({'australian capital territory': 'act',
#   'new south wales': 'nsw',
#   'northern territory': 'nt',
#   'queensland': 'qld',
#   'south australia': 'sa',
#   'tasmania': 'tas',
#   'victoria': 'vic',
#   'western australia': 'wa'},
#  {'canberra': 'can',
#   'sydney': 'syd',
#   'darwin': 'dar',
#   'brisbane': 'bri',
#   'adelaide': 'ade',
#   'hobart': 'hob',
#   'melbourne': 'mel',
#   'perth': 'per'})

# %%
df.head()
# Out:
#    Unnamed: 0                  _id               author    location    gcc
# 0           0  1412193949943402498  1400239891590520835  picton nsw  1gsyd
# 1           1  1412194010312019986  1400239891590520835  picton nsw  1gsyd
# 2           2  1412198081760694273  1400239891590520835  picton nsw  1gsyd
# 3           3  1412185070224351232            113000840  melton vic  2gmel
# 4           4  1412184979849678849           1199031211    perth wa  5gper

# %%
def normalise_location(location: str) -> str:
    text = location.lower()
    
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r' - ', '', text)
    
    for key, value in state_location.items():
        text = re.sub(key, value, text)

    return text

# %%
df.location = df.agg(lambda x: normalise_location(x.location), axis=1)

# %%
sal_df.head()
# Out:
#          location    gcc          location_x
# 0      abbotsbury  1gsyd      abbotsbury syd
# 1  abbotsford nsw  1gsyd  abbotsford nsw syd
# 2  acacia gardens  1gsyd  acacia gardens syd
# 3     agnes banks  1gsyd     agnes banks syd
# 4           airds  1gsyd           airds syd

# %%
import textdistance

# %%
string1 = df.location[0]

# %%
INVALID_LOCATION = ['act australia', 
                'nsw australia', 
                'nt australia', 
                'qld Australia', 
                'sa australia', 
                'tas australia', 'vic australia', 
                'wa australia', 'australia']

def is_state_location(location):
    if location in INVALID_LOCATION:
        return True
    return False

# %%
def location_similarity(location, sal_df, threshold = 0.9) -> float:
    df = sal_df[['gcc', 'location_x']].copy()
    df['similarity'] = df.location_x.apply(lambda x: textdistance.jaro_winkler(location, x)) 
    rdf = df[df.similarity > threshold]
    if rdf.empty:
        return np.nan
    return rdf.loc[df.similarity.idxmax()]['gcc']

# %%
pd.merge(df, sal_df, left_on='location', right_on='location')
# Out:
#     Unnamed: 0                  _id               author      location  gcc_x  \
# 0            0  1412193949943402498  1400239891590520835    picton nsw  1gsyd
# 1            1  1412194010312019986  1400239891590520835    picton nsw  1gsyd
# 2            2  1412198081760694273  1400239891590520835    picton nsw  1gsyd
# 3            3  1412185070224351232            113000840    melton vic  2gmel
# 4            4  1412184979849678849           1199031211      perth wa  5gper
# ..         ...                  ...                  ...           ...    ...
# 83          83  1412196248912760835           1351649162  canberra act  8acte
# 84          84  1412197623805603840  1027167886148689920  canberra act  8acte
# 85          85  1412198117932371969  1348502962050535428  canberra act  8acte
# 86          86  1412198454407794689            137315172  canberra act  8acte
# 87          87  1412185329184821253           3306424254  canberra act  8acte
#
#     gcc_y        location_x
# 0   1gsyd    picton nsw syd
# 1   1gsyd    picton nsw syd
# 2   1gsyd    picton nsw syd
# 3   2gmel    melton vic mel
# 4   5gper      perth wa per
# ..    ...               ...
# 83  8acte  canberra act cte
# 84  8acte  canberra act cte
# 85  8acte  canberra act cte
# 86  8acte  canberra act cte
# 87  8acte  canberra act cte
#
# [88 rows x 7 columns]

# %%
pd.DataFrame(df.value_counts('author'), columns=['tweet_count']).reset_index()
# Out:
#                  author  tweet_count
# 0              51378153           32
# 1              30839139            7
# 2            1199031211            4
# 3   1147292655673434112            4
# 4              14156860            3
# 5   1400239891590520835            3
# 6   1348502962050535428            2
# 7             157568648            2
# 8   1002522913235300352            2
# 9            3306424254            2
# 10           3005691210            2
# 11             74676960            1
# 12           1943195658            1
# 13  1283885249458352128            1
# 14             42571871            1
# 15  1027167886148689920            1
# 16   892273046634979332            1
# 17   790523618736287744            1
# 18   771176061589557248            1
# 19           4475561478            1
# 20           2492242742            1
# 21           1925513276            1
# 22            113000840            1
# 23           1351649162            1
# 24             51404228            1
# 25             15011950            1
# 26            833343482            1
# 27            625312424            1
# 28            611514477            1
# 29            596504235            1
# 30            575047568            1
# 31            556481489            1
# 32            378503524            1
# 33            303025191            1
# 34            137315172            1
# 35            965958252            1

# %%
# %%time
df['gcc'] = df.agg(lambda x: location_similarity(x.location, sal_df=sal_df), axis=1)
# Out:
# CPU times: user 51.9 s, sys: 6 µs, total: 51.9 s
# Wall time: 51.9 s

# %%
sal_df
# Out:
#               location    gcc            location_x
# 0           abbotsbury  1gsyd        abbotsbury syd
# 1       abbotsford nsw  1gsyd    abbotsford nsw syd
# 2       acacia gardens  1gsyd    acacia gardens syd
# 3          agnes banks  1gsyd       agnes banks syd
# 4                airds  1gsyd             airds syd
# ...                ...    ...                   ...
# 3389  christmas island  9oter  christmas island ter
# 3390       home island  9oter       home island ter
# 3391        jervis bay  9oter        jervis bay ter
# 3392    norfolk island  9oter    norfolk island ter
# 3393       west island  9oter       west island ter
#
# [3394 rows x 3 columns]

# %%
df
# Out:
#      Unnamed: 0                  _id               author           location  \
# 8             8  1412191471680118784            226175896  central coast nsw
# 9             9  1412192672547147778   835809553589526530  central coast nsw
# 10           10  1412192775479595008  1211985166886817796  central coast nsw
# 11           11  1412193056258805762  1289467509364547584  central coast nsw
# 17           17  1412196428869369856  1008365059381256196  central coast nsw
# ..          ...                  ...                  ...                ...
# 710         710  1412198117932371969  1348502962050535428       canberra act
# 711         711  1412198454407794689            137315172       canberra act
# 712         712  1412185329184821253           3306424254       canberra act
# 713         713  1412190755452424209              7598552   braddon canberra
# 714         714  1412197569585848320  1397010827048194048  fyshwick canberra
#
#        gcc
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 17     NaN
# ..     ...
# 710  8acte
# 711  8acte
# 712  8acte
# 713  8acte
# 714  8acte
#
# [676 rows x 5 columns]

# %%
df
# Out:
#      Unnamed: 0                  _id               author           location  \
# 8             8  1412191471680118784            226175896  central coast nsw
# 9             9  1412192672547147778   835809553589526530  central coast nsw
# 10           10  1412192775479595008  1211985166886817796  central coast nsw
# 11           11  1412193056258805762  1289467509364547584  central coast nsw
# 17           17  1412196428869369856  1008365059381256196  central coast nsw
# ..          ...                  ...                  ...                ...
# 710         710  1412198117932371969  1348502962050535428       canberra act
# 711         711  1412198454407794689            137315172       canberra act
# 712         712  1412185329184821253           3306424254       canberra act
# 713         713  1412190755452424209              7598552   braddon canberra
# 714         714  1412197569585848320  1397010827048194048  fyshwick canberra
#
#        gcc
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 17     NaN
# ..     ...
# 710  8acte
# 711  8acte
# 712  8acte
# 713    NaN
# 714    NaN
#
# [676 rows x 5 columns]

# %%
sal_df['similarity'] = sal_df.agg(lambda x: location_similarity(x.location, string1), axis=1)
sal_df
# Out:
#                location  ste    gcc  sal  similarity
# 0            abbotsbury    1  1gsyd    1    0.531481
# 1        abbotsford nsw    1  1gsyd    1    0.493386
# 2        acacia gardens    1  1gsyd    1    0.504233
# 3           agnes banks    1  1gsyd    1    0.535354
# 4                 airds    1  1gsyd    1    0.533333
# ...                 ...  ...    ...  ...         ...
# 15335  christmas island    9  9oter    9    0.595569
# 15336       home island    9  9oter    9    0.519360
# 15337        jervis bay    9  9oter    9    0.448148
# 15338    norfolk island    9  9oter    9    0.493386
# 15339       west island    9  9oter    9    0.603367
#
# [15340 rows x 5 columns]

# %%
sal_df[sal_df.similarity > 0.98].empty
# Out:
# True

# %%
df.location[5]
# Out:
# 'nsw australia'

# %%
is_state_location(df.location[5])
# Out:
# True

# %%
'Macquarie Park Syd'.lower() in list(sal_df.location)
# Out:
# False

# %%
'Darwin'.lower() in list(sal_df.location)
# Out:
# True

# %%
'central coast nsw' in list(sal_df.location)
# Out:
# False

# %%
sal_df[sal_df['location_x'].apply(lambda x: textdistance.jaro_winkler(x, 'darwin')) > 0.9]
# Out:
#       location    gcc  location_x
# 14915   darwin  7gdar  darwin dar

# %%
sal_df.location.unique()
# Out:
# array(['abbotsbury', 'abbotsford nsw', 'acacia gardens', ...,
#        'jervis bay', 'norfolk island', 'west island'], dtype=object)

# %%
rdf1 = pd.read_csv("../data/result/task1.csv")

# %%
rdf1
# Out:
#       gcc   _id
# 0   1gsyd     4
# 1   2gmel    35
# 2   1gsyd     4
# 3   3gbri     6
# 4   4gade    12
# 5   5gper  1537
# 6   8acte   568
# 7   1gsyd     3
# 8   2gmel    38
# 9   3gbri     9
# 10  4gade    37
# 11  1gsyd     4
# 12  2gmel     8
# 13  5gper  1235
# 14  7gdar     1
# 15  8acte   483
# 16  1gsyd     1
# 17  2gmel    26
# 18  3gbri     9
# 19  4gade    20
# 20  5gper  1485
# 21  6ghob     1
# 22  8acte   505
# 23  1gsyd     3
# 24  2gmel    23
# 25  1gsyd     2
# 26  2gmel     2
# 27  3gbri    25
# 28  4gade    29
# 29  5gper  1362
# 30  8acte   508
# 31  2gmel     7
# 32  3gbri    10
# 33  4gade    49
# 34  5gper  1340
# 35  8acte   467

# %%
rdf1.groupby('gcc').sum().reset_index()
# Out:
#      gcc   _id
# 0  1gsyd    21
# 1  2gmel   139
# 2  3gbri    59
# 3  4gade   147
# 4  5gper  6959
# 5  6ghob     1
# 6  7gdar     1
# 7  8acte  2531

# %%
df[['author', 'gcc']].groupby(['author']).nunique().reset_index()
# Out:
#                  author  gcc
# 0              14156860    1
# 1              15011950    1
# 2              30839139    1
# 3              42571871    1
# 4              51378153    1
# 5              51404228    1
# 6              74676960    1
# 7             113000840    1
# 8             137315172    1
# 9             157568648    1
# 10            303025191    1
# 11            378503524    1
# 12            556481489    1
# 13            575047568    1
# 14            596504235    1
# 15            611514477    1
# 16            625312424    1
# 17            833343482    1
# 18            965958252    1
# 19           1199031211    1
# 20           1351649162    1
# 21           1925513276    1
# 22           1943195658    1
# 23           2492242742    1
# 24           3005691210    1
# 25           3306424254    1
# 26           4475561478    1
# 27   771176061589557248    1
# 28   790523618736287744    1
# 29   892273046634979332    1
# 30  1002522913235300352    1
# 31  1027167886148689920    1
# 32  1147292655673434112    1
# 33  1283885249458352128    1
# 34  1348502962050535428    1
# 35  1400239891590520835    1
